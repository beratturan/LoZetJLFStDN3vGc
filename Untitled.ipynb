# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import ShuffleSplit

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#    Y  X1  X2  X3  X4  X5  X6
# 0  0   3   3   3   4   2   4
# 1  0   3   2   3   5   4   3
# 2  1   5   3   3   3   3   5
# 3  0   5   4   3   3   3   5
# 4  0   5   4   3   3   3   5

# %%
data.isnull().sum()
# Out:
# Y     0
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# dtype: int64

# %%
data.describe()
# Out:
#                 Y          X1          X2          X3          X4          X5  \
# count  126.000000  126.000000  126.000000  126.000000  126.000000  126.000000
# mean     0.547619    4.333333    2.531746    3.309524    3.746032    3.650794
# std      0.499714    0.800000    1.114892    1.023440    0.875776    1.147641
# min      0.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      0.000000    4.000000    2.000000    3.000000    3.000000    3.000000
# 50%      1.000000    5.000000    3.000000    3.000000    4.000000    4.000000
# 75%      1.000000    5.000000    3.000000    4.000000    4.000000    4.000000
# max      1.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#                X6
# count  126.000000
# mean     4.253968
# std      0.809311
# min      1.000000
# 25%      4.000000
# 50%      4.000000
# 75%      5.000000
# max      5.000000

# %%
len(data)
# Out:
# 126

# %%
X = data.drop('Y', axis=1)
y = data['Y']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
k_range = range(1,26)
scores = {}
scores_list = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    y_pred = knn.predict(X_test)
    scores[k] = metrics.accuracy_score(y_test,y_pred)
    scores_list.append(metrics.accuracy_score(y_test,y_pred))

# %%
plt.plot(k_range,scores_list)

# %%
knn = KNeighborsClassifier(n_neighbors=16)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.7692307692307693

# %%
from sklearn.metrics import mean_absolute_error
list_training_error = []
list_testing_error = []
#Let's try to drop the questions 
for i in range(1,7):
    question = "X" + str(i)
    X = data.drop('Y', axis=1)
    X = data.drop(question, axis=1)
    y = data['Y']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20,random_state=42)
    knn = KNeighborsClassifier(n_neighbors=16)
    knn.fit(X_train,y_train)
    y_pred = knn.predict(X_test)
    print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.8461538461538461
# 0.9230769230769231
# 0.7692307692307693
# 0.8076923076923077
# 0.8076923076923077
# 0.7307692307692307

# %%
#Except the 5th and 3th questions, removing remaining questions increased our accuracy.So we should keep 5th and 3th question
#Also removing Second questions had most effect to accuracy so we can drop it too.
train_scores = []
test_scores = []
X = data.drop('Y', axis=1)
X = data.drop("X2", axis=1)
y = data['Y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20,random_state=42)
knn = KNeighborsClassifier(n_neighbors=16)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9230769230769231
